# %%
passenger_name = "Rahul Sharma"
passenger_age = 28
gender = "Male"
mobile_Number = 9876543210
print("passenger_name :", passenger_name)
print("Passenger_age:", passenger_age)
print("Gender:", gender)
print("Mobile_Number:", mobile_Number)
# Out:
# passenger_name : Rahul Sharma
# Passenger_age: 28
# Gender: Male
# Mobile_Number: 9876543210

# %%
train_name = "Rajdhani Express"
seat_number = "B2-45"
ticket_price = 2450
journey_date = "25-May-2026"
print("Train Name :", train_name)
print("Seat Number :", seat_number)
print("Ticket Price :", ticket_price)
print("Journey Date :", journey_date)
# Out:
# Train Name : Rajdhani Express
# Seat Number : B2-45
# Ticket Price : 2450
# Journey Date : 25-May-2026

# %%
a = 4
b = 2
print(a/b)
print (a%b)
print(a//b)
# Out:
# 2.0
# 0
# 2

# %%
a = 5
b = 4
print(a>b)
print(a<b)
print(a>=9)
print(a==5)
print(a==0)
# Out:
# True
# False
# False
# True
# False

# %%
a = 4
b = 2
print(a&b>2)
print(a!=5)
print(a|b>2)
# Out:
# False
# True
# True

# %%
number_of_passenger = 3
ticket_price = 2450
total_fare = number_of_passenger * ticket_price
print("total_fare:", total_fare)
gst_percentage = 5
gst_amount = (total_fare * gst_percentage) / 100
print("gst_amount:", gst_amount)
final_amount = total_fare + gst_amount
print("final_amount:", final_amount)
# Out:
# total_fare: 7350
# gst_amount: 367.5
# final_amount: 7717.5

# %%
print("------Indian Railway Ticket------")
print("Passenger Name:", passenger_name)
print("Train Name:", train_name)
print("Seat Number:", seat_number)
print("Journey date:", journey_date)
print("Passengers:", number_of_passenger)
print("Ticket fare:", total_fare)
print("GST Amount:", gst_amount)
print ("Final Amount:", final_amount)
print("---------------------------------")
# Out:
#   File "/tmp/ipykernel_2424/2063644312.py", line 2
#     print("Passenger Name:" passenger_name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("----------- Indian Railways Ticket -----------")
print("Passenger Name :", passenger_name)
print("Train Name :", train_name)
print("Seat Number:", seat_number)
print("Journey Date:", journey_date)
print("Passengers :", number_of_passenger)
print("Ticket Fare :", total_fare)
print("GST Amount :", gst_amount)
print("Final Amount :", final_amount)
print("----------------------------------------------")
# Out:
# ----------- Indian Railways Ticket -----------
# Passenger Name : Rahul Sharma
# Train Name : Rajdhani Express
# Seat Number: B2-45
# Journey Date: 25-May-2026
# Passengers : 3
# Ticket Fare : 7350
# GST Amount : 367.5
# Final Amount : 7717.5
# ----------------------------------------------
