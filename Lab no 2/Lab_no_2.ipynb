# %%
train_name = "Rajdhani Express"
train_number = 12951
source_station = "Mumbai"
destination_station = "Delhi"
ticket_price = 2450.75
a = "*"

# %%
print("Welcome to Indian Railway Reservation System")
print("Train Name :", train_name,"...",a)
print("Train Number :", train_number,"...",a)
print("Source Station :", source_station,"...",a)
print("Destination Station :", destination_station,"...",a)
# Out:
# Welcome to Indian Railway Reservation System
# Train Name : Rajdhani Express ... *
# Train Number : 12951 ... *
# Source Station : Mumbai ... *
# Destination Station : Delhi ... *

# %%
print("Welcome to Indian Railway Reservation System")
print("Train Name :", train_name)
print("Train Number :", train_number)
print("Source Station :", source_station)
print("Destination Station :", destination_station)
# Out:
# Welcome to Indian Railway Reservation System
# Train Name : Rajdhani Express
# Train Number : 12951
# Source Station : Mumbai
# Destination Station : Delhi

# %%
print(type(train_name))
print(type(train_number))
print(type(ticket_price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
print(type(train_name))
print(type(train_number))
print(type(ticket_price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2-45"
is_confirmed = True

# %%
ticket_price_integer = int(ticket_price)
print(type(ticket_price_integer))
# Out:
# <class 'int'>

# %%
train_number_string = str(train_number)
print(type(train_number_string))
# Out:
# <class 'str'>

# %%
sname = "OKOK"
smarks = 66
print("Student Name :  ", sname,"\nStudent Marks :", smarks)
# Out:
#   File "/tmp/ipykernel_1028/441333415.py", line 3
#     print("Student Name :  ", sname,"\nStudent Marks ": smarks)
#                                                       ^
# SyntaxError: invalid syntax

# %%
sname = "OKOK"
smarks = 66
print("Student Name : ", sname,"\nStudent Marks :", smarks )
# Out:
# Student Name :  OKOK
# Student Marks : 66

# %%
print(f"Student Name :{sname}\nStudent Marks : {smarks}")
# Out:
# Student Name :OKOK
# Student Marks : 66

# %%
sname = input("Enter Your Name:  ")
print(sname)
# Out:
# Enter Your Name:  OKOK
# OKOK

# %%
smarks = int(input("Enter Your Marks:  "))

print(smarks)
print (sname,smarks)
new_smarks = smarks+5
print(sname,New_smarks)
# Out:
# Enter Your Marks:  66
# 66
# OKOK 66
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1028/147460026.py in <cell line: 0>()
#       4 print (sname,smarks)
#       5 new_smarks = smarks+5
# ----> 6 print(sname,New_smarks)
#
# NameError: name 'New_smarks' is not defined
