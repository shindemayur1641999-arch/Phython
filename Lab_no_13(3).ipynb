# %%
def sq (a):
  sq = a * a

  return sq
sq(5)
# Out:
# 25

# %%
sq = lambda a: a * a
print(sq(5))
# Out:
# 25

# %%
sq = lambda a,b:a*b
print(sq(2,3))
# Out:
# 6

# %%
ticket_fares = [100, 200, 300, 400]

# %%
updated_fares = list(

   map(
       lambda fare: fare + 100,
       ticket_fares))

# %%
updated_fares = list(
   map(
       lambda fare: fare + 100,
       ticket_fares))

# %%
print(updated_fares)
# Out:
# [200, 300, 400, 500]

# %%
print(updated_fares)
# Out:
# [200, 300, 400, 500]

# %%
updated_fares = list(

   map(
       lambda fare: fare + 100,
       ticket_fares))
fare =[100,200,300]
print(updated_fares)
# Out:
# [200, 300, 400, 500]

# %%
discount_fare = lambda fare: fare - 200
print("Discounted Fare :", discount_fare(2500))
# Out:
# Discounted Fare : 2300

# %%
print("Discounted Fare :", discount_fare(2500))
# Out:
# Discounted Fare : 2300

# %%
ticket_fares = [100,200,300]
updated_fares = list(

   map(
       lambda fare: fare + 100,
       ticket_fares))
print(updated_fares)
# Out:
# [200, 300, 400]

# %%
reservation_status = [
   "Confirmed",
   "Waiting",
   "Confirmed",
   "RAC"]

# %%
confirmed_tickets = list(
   filter(
       lambda status: status == "Confirmed",
       reservation_status))

# %%
print(confirmed_tickets)
# Out:
# ['Confirmed', 'Confirmed']

# %%
passengers = [
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma"]

seats = [
   "B1-21",
   "B1-22",
   "B1-23"]

# %%
reservation_data = list(
   zip(passengers, seats))

# %%
print(reservation_data)
# Out:
# [('Rahul Sharma', 'B1-21'), ('Priya Singh', 'B1-22'), ('Amit Verma', 'B1-23')]

# %%
passenger_list = [
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma"]

# %%
for index, passenger in enumerate(passenger_list):
   print(index, passenger)
# Out:
# 0 Rahul Sharma
# 1 Priya Singh
# 2 Amit Verma

# %%
ticket_fares = [2500, 800, 3200, 600]

# %%
valid_fares = list(
   filter(
       lambda fare: fare > 1000,
       ticket_fares))

# %%
final_fares = list(
   map(
       lambda fare: fare + 100,
       valid_fares))

# %%
passengers = ["Rahul", "Priya", "Amit"]
seats = ["S1", "S2", "S3"]
fares = [2500, 1800, 3200]

# %%
reservation_data = list(
   zip(passengers, seats, fares))

# %%
print("===================================")
print(" Railway Reservation Report ")
print("===================================")

for index, data in enumerate(reservation_data):

   passenger, seat, fare = data

   final_fare = (lambda x: x - 100)(fare)

   print("Reservation ID :", index + 1)
   print("Passenger :", passenger)
   print("Seat :", seat)
   print("Final Fare :", final_fare)
   print("-----------------------------------")
# Out:
# ===================================
#  Railway Reservation Report
# ===================================
# Reservation ID : 1
# Passenger : Rahul
# Seat : S1
# Final Fare : 2400
# -----------------------------------
# Reservation ID : 2
# Passenger : Priya
# Seat : S2
# Final Fare : 1700
# -----------------------------------
# Reservation ID : 3
# Passenger : Amit
# Seat : S3
# Final Fare : 3100
# -----------------------------------

# %%
discount_fare = lambda fare: fare - 200
print("Discounted Fare :", discount_fare(2500))
# Out:
# Discounted Fare : 2300

# %%
l1=[4,9,6,2]
l2 = list(map(lambda num:num*num,l1))
print(l2)
# Out:
# [16, 81, 36, 4]

# %%
l8 = lambda num:num*5
l8 =
print(18)
# Out:
# <function <lambda> at 0x791dbf8f1da0>

# %%
# lambda  One lne anoymous fun
# map() apply lambda fun on each value
# filter() Find out the value base of condition
# zip() Combine tow or more list member  passengers = [
#    "Rahul Sharma",
#    "Priya Singh",
#    "Amit Verma"]

# seats = [
#    "B1-21",
#    "B1-22",
#    "B1-23"]
#    reservation_data = list(
#    zip(passengers, seats))
#    out put (rahul sharma B1-21)
#    enmrrate return index + value
