# %%
passenger_name = " Rahul Sharma"
train_name = "Rajdhani express"
print ("Original Passanger Name:", passenger_name)
print ("Uppercase Name:", passenger_name.upper())
print ("Formatted Name:", passenger_name.strip(). title())
print("Train Name:", train_name.upper())
Updated_train = train_name.replace("Rajdhani", "Vande Bharat")
print("Updated train name:",Updated_train)
# Out:
# Original Passanger Name:  Rahul Sharma
# Uppercase Name:  RAHUL SHARMA
# Formatted Name: Rahul Sharma
# Train Name: RAJDHANI EXPRESS
# Updated train name: Vande Bharat express

# %%
passenger_name = "Priya Patel"
train_number = 12951
seat_number = "B2-45"
fare = 1250
print(f"Passenger Name: {passenger_name}")
print(f"Train Number: {train_number}")
print(f"Seat Number: {seat_number}")
print(f"fare: ₹{fare}")
# Out:
# Passenger Name: Priya Patel
# Train Number: 12951
# Seat Number: B2-45
# fare: ₹1250

# %%
ticket_id = "WRB24567"
ZONE = ticket_id[0:2]
coach = ticket_id[2:4]
ticket_number = ticket_id[4:]
print("Ticket Id:", ticket_id)
print("Railway Zone:", ZONE)
print("Coach Number:", coach)
print("Ticket Number:", ticket_number)
# Out:
# Ticket Id: WRB24567
# Railway Zone: WR
# Coach Number: B2
# Ticket Number: 4567

# %%
passenger_name = " Rahul Sharma"
print("Name of Passenger:", passenger_name.upper())
print("name of Passanger:", passenger_name.lower())
print("name of Passenger:", passenger_name.title())
print("Name of Passenger:", passenger_name.strip())
print("Name of Passenger@:", passenger_name.strip().title())
print("Name of Passenger:", passenger_name.replace("Sharma","Verma"))
# Out:
# Name of Passenger:  RAHUL SHARMA
# name of Passanger:  rahul sharma
# name of Passenger:  Rahul Sharma
# Name of Passenger: Rahul Sharma
# Name of Passenger@: Rahul Sharma
# Name of Passenger:  Rahul Verma

# %%
Name_plate = "MH01AB1234"
State = Name_plate[0:2]
State Number = Name_plate[2:4]
Series_code = Name_plate[4:6]
Unique_Number = Name_plate[6:]
print(Name_plate.strip())
print(State)
print(State Number)
print(Series_code)
print(Unique_Number
# Out:
#   File "/tmp/ipykernel_965/3782515653.py", line 3
#     State Number = Name_plate[2:4]
#           ^
# SyntaxError: invalid syntax

# %%
Name_plate = "MH01AB1234"
owner_name = "okok"
State = Name_plate[0:2]
State_Number = Name_plate[2:4]
Series_code = Name_plate[4:6]
Unique_Number = Name_plate[6:]
print("Name Of Owner:", owner_name.upper())
print("Bike Number:", Name_plate.strip()[0:10])
print("Plate Name:",Name_plate.strip())
print("State Name:",State)
print("State Name:",State_Number)
print("Series Code:",Series_code)
print("Unique Number:",Unique_Number))
# Out:
#   File "/tmp/ipykernel_965/3023621569.py", line 14
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
Name_plate = "MH01AB1234"
owner_name = "okok"
State = Name_plate[0:2]
State_Number = Name_plate[2:4]
Series_code = Name_plate[4:6]
Unique_Number = Name_plate[6:]
print("Name Of Owner:", owner_name.upper())
print("Bike Number:", Name_plate.strip()[0:10])
print("Plate Name:",Name_plate.strip())
print("State Name:",State)
print("State Name:",State_Number)
print("Series Code:",Series_code)
print("Unique Number:",Unique_Number)
# Out:
# Name Of Owner: OKOK
# Bike Number: MH01AB1234
# Plate Name: MH01AB1234
# State Name: MH
# State Name: 01
# Series Code: AB
# Unique Number: 1234
