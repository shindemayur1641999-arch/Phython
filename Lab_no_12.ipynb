# %%
1.function with parameter
2.fun with default parameter
3.* args
4.**kwargs

# %%
def greet(name):
    print("Hello,", name)
greet("Alice")
# Out:
# Hello, Alice

# %%
def reservation_status(
   passenger_name,
   ticket_status="Confirmed"):
   print("Passenger Name :", passenger_name)
   print("Ticket Status :", ticket_status)

# %%
reservation_status("Rahul Sharma")
reservation_status("Amit Verma", "Waiting")
# Out:
# Passenger Name : Rahul Sharma
# Ticket Status : Confirmed
# Passenger Name : Amit Verma
# Ticket Status : Waiting

# %%
def passenger_booking(*passengers):
   print("Passenger List:")
   for name in passengers:
       print("Passenger :", name)

# %%
passenger_booking(
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma",
   "Neha Kapoor")
# Out:
# Passenger List:
# Passenger : Rahul Sharma
# Passenger : Priya Singh
# Passenger : Amit Verma
# Passenger : Neha Kapoor

# %%
def ticket_details(**details):
   print("Ticket Information:")
   for key, value in details.items():
       print(key, ":", value)
ticket_details(
   passenger_name="Rahul Sharma",
   train_name="Rajdhani Express",
   seat_number="B1-21",
   fare=2500,
   status="Confirmed")
# Out:
# Ticket Information:
# passenger_name : Rahul Sharma
# train_name : Rajdhani Express
# seat_number : B1-21
# fare : 2500
# status : Confirmed

# %%
ticket_details(
   passenger_name="Rahul Sharma",
   train_name="Rajdhani Express",
   seat_number="B1-21",
   fare=2500,
   status="Confirmed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_606/679458920.py in <cell line: 0>()
# ----> 1 ticket_details(
#       2    passenger_name="Rahul Sharma",
#       3    train_name="Rajdhani Express",
#       4    seat_number="B1-21",
#       5    fare=2500,
#
# NameError: name 'ticket_details' is not defined

# %%
ticket_details(
   passenger_name="Rahul Sharma",
   train_name="Rajdhani Express",
   seat_number="B1-21",
   fare=2500,
   status="Confirmed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_606/679458920.py in <cell line: 0>()
# ----> 1 ticket_details(
#       2    passenger_name="Rahul Sharma",
#       3    train_name="Rajdhani Express",
#       4    seat_number="B1-21",
#       5    fare=2500,
#
# NameError: name 'ticket_details' is not defined

# %%
ticket_details(
   passenger_name="Rahul Sharma",
   train_name="Rajdhani Express",
   seat_number="B1-21",
   fare=2500,
   status="Confirmed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_606/679458920.py in <cell line: 0>()
# ----> 1 ticket_details(
#       2    passenger_name="Rahul Sharma",
#       3    train_name="Rajdhani Express",
#       4    seat_number="B1-21",
#       5    fare=2500,
#
# NameError: name 'ticket_details' is not defined

# %%
def welcome_message():
  print("----------")
  print("Indian Railways")
  print("----------")
  print("Welcome to Indian Railways")
welcome_message()
# Out:
# ----------
# Indian Railways
# ----------
# Welcome to Indian Railways

# %%
for _ in range(3):
  welcome_message()
# Out:
#   File "/tmp/ipykernel_606/2345870841.py", line 2
#     while x>=3:
#                ^
# SyntaxError: incomplete input

# %%
for _ in range(3):
  welcome_message()
# Out:
#   File "/tmp/ipykernel_606/2223768602.py", line 3
#     for i in range(3):
#     ^
# IndentationError: expected an indented block after 'while' statement on line 2

# %%
x=3
while x>=3:
for _ in range(3):
  welcome_message()
# Out:
#   File "/tmp/ipykernel_606/3443505839.py", line 3
#     for _ in range(3):
#     ^
# IndentationError: expected an indented block after 'while' statement on line 2

# %%
def welcome_message():
  print("----------")
  print("Indian Railways")
  print("----------")
  print("Welcome to Indian Railways")
for i in range(3):
  welcome_message()
# Out:
# ----------
# Indian Railways
# ----------
# Welcome to Indian Railways
# ----------
# Indian Railways
# ----------
# Welcome to Indian Railways
# ----------
# Indian Railways
# ----------
# Welcome to Indian Railways

# %%
def reservation_status(passenger_name="OKOK", ticket_status="Confirm"):
  print("passenger Name:", passenger_name)
  print("Ticket Status:", ticket_status)
reservation_status()
# Out:
# passenger Name: OKOK
# Ticket Status: Confirm

# %%
def passenger_booking(*Passenger):
  print("Passenger List:")
  for i in Passenger:
    print("passenger :",i)
    passenger_booking("OKOK","OKOK2")

# %%
def verify_passenger(passenger_number):
   if passenger_number == 0:
       print("Verification Completed")
       return
   print("Verifying Passenger :", passenger_number)
   verify_passenger(passenger_number - 1)
verify_passenger(3)
# Out:
# Verifying Passenger : 3
# Verifying Passenger : 2
# Verifying Passenger : 1
# Verification Completed

# %%
def seats_countdown(seats):
  if seats == 0:
     print("All seats Booked")
     return
  print("Remaing Seats:", seats)
  seats_countdown(seats-1)
seats_countdown(10)
# Out:
# Remaing Seats: 10
# Remaing Seats: 9
# Remaing Seats: 8
# Remaing Seats: 7
# Remaing Seats: 6
# Remaing Seats: 5
# Remaing Seats: 4
# Remaing Seats: 3
# Remaing Seats: 2
# Remaing Seats: 1
# All seats Booked
